# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


def my_line(x, m, q):
    y = m * x + q
    return y


my_dataset = pd.read_excel('Smith_glass_post_NYT_data.xlsx', sheet_name='Supp_majors', engine='openpyxl')

my_dataset1 = my_dataset[my_dataset.Epoch == 'one']
my_dataset2 = my_dataset[my_dataset.Epoch == 'two']

x = np.linspace(52.5, 62, 100)
y = my_line(x, m=0.3, q=-10.3)

fig, ax = plt.subplots()

ax.scatter(my_dataset1.SiO2, my_dataset1.F, marker='x', color="#900C9E", edgecolor="#D8DB15", label=r'$1^{st}$ Epoch')
ax.scatter(my_dataset2.SiO2, my_dataset2.F, marker='o', color="#19da3c", edgecolor="#C9AD22", label=r'$2^{nd}$ Epoch')
ax.plot(x, y, color="#080715")

ax.annotate(r'What is the 1$\sigma$ for this point?', xy=(47.6, 6.6), xytext=(47, 8.8), arrowprops=dict(arrowstyle="->", connectionstyle="arc3"))
ax.text(52.4, 5.6, r'$ Na_2O = 0.3 \cdot SiO_2 -10.3$', dict(size=10, rotation=33))

ax.text(53.5, 5.3, r'$ \mu_{SiO_2} = \frac {a_{1}+a_{2}+\cdots +a_{n}}{n}$ = ' + '{:.1f} [wt.%]'.format(57.721),  dict(size=11.5))

ax.set_xlabel(r'SiO$_2$ [wt%]')
ax.set_ylabel(r'K$_2$O [wt%]')

ax.legend()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18744\678747388.py:21: UserWarning: You passed a edgecolor/edgecolors ('#D8DB15') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(my_dataset1.SiO2, my_dataset1.F, marker='x', color="#900C9E", edgecolor="#D8DB15", label=r'$1^{st}$ Epoch')

# %%
my_dataset1
# Out:
#       Analysis no.  Stat. pos. Eruption  controlcode_old  controlcode Epoch  \
# 942            943          30   Casale                0            3   one
# 943            944          30   Casale                0            3   one
# 944            945          30   Casale                0            3   one
# 945            946          30   Casale                0            3   one
# 946            947          30   Casale                0            3   one
# ...            ...         ...      ...              ...          ...   ...
# 1772          1773           3    Gauro                0            3   one
# 1773          1774           3    Gauro                0            3   one
# 1774          1775           3    Gauro                0            3   one
# 1775          1776           3    Gauro                0            3   one
# 1776          1777           3    Gauro                0            3   one
#
#      Analysis label  Date of analysis    Na2O     MgO  ...     SiO2     K2O  \
# 942         cf112_8            190110  3.6130  0.6357  ...  58.5136  8.6093
# 943         cf112_9            190110  3.8078  0.6430  ...  58.9160  8.6592
# 944        cf112_13            190110  3.7035  0.6604  ...  58.8905  8.7561
# 945        cf112_14            190110  3.8009  0.6020  ...  59.5349  8.7479
# 946         cf112_2            190110  3.7155  0.6442  ...  60.1133  8.6304
# ...             ...               ...     ...     ...  ...      ...     ...
# 1772        cf94_15            210110  3.3614  1.0967  ...  56.8972  8.4456
# 1773         cf94_7            210110  3.1947  1.2564  ...  56.6850  8.4103
# 1774         cf94_3            210110  3.4839  1.2406  ...  56.0473  8.5309
# 1775        cf94_13            210110  3.4123  1.2520  ...  57.0092  8.3925
# 1776         cf94_5            210110  3.5831  1.0524  ...  57.3721  8.7455
#
#          CaO    TiO2     MnO     FeO    P2O5      Cl   F    Total
# 942   2.5891  0.3761  0.0804  3.5272  1478.0  6953.0 NaN  96.0026
# 943   2.5309  0.3923  0.1542  3.5988  1402.0  6660.0 NaN  97.0112
# 944   2.6366  0.4163  0.1634  3.4819  1017.0  7134.0 NaN  97.1166
# 945   2.5012  0.3796  0.1021  3.2041  1440.0  6921.0 NaN  97.4344
# 946   2.5687  0.4121  0.1454  3.6097  1589.0  6952.0 NaN  98.4292
# ...      ...     ...     ...     ...     ...     ...  ..      ...
# 1772  4.0152  0.5207  0.0490  4.5063  2540.0  5100.0 NaN  97.9950
# 1773  4.0573  0.5213  0.1336  4.5829  2498.0  4653.0 NaN  98.1024
# 1774  3.9605  0.5579  0.1969  4.6090  2540.0  5002.0 NaN  98.1349
# 1775  3.9460  0.6006  0.1727  4.2875  2553.0  4951.0 NaN  98.5576
# 1776  3.7350  0.5468  0.1513  4.5423  2449.0  5151.0 NaN  99.1281
#
# [835 rows x 21 columns]
